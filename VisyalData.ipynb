# %%
import matplotlib.pyplot as plt
import math

# %%
data = range(10)
print(data)
# Out:
# range(0, 10)

# %%
plt.plot(data)

# %%
plt.plot(data, color = [1, 0.5, 0])

# %%
# ?plt.plot

# %%
plt.plot(data, 'o')

# %%
plt.figure(figsize=(10, 6))
plt.grid()
plt.plot(data)

# %%
plt.title('Русс наз')
plt.plot(data)

# %%
plt.title(u'название', family='verdana')
plt.grid()
plt.xlabel(u'ось х', family='verdana')
plt.ylabel(u'ось y', family='verdana')
plt.text(6, 6, u'ОЧВ', family='verdana')
plt.plot(data)

# %%
plt.grid()
plt.text(6, 6, u'ОЧВ', family='verdana')
plt.arrow(6,1, -2, 2, width = 0.3)
plt.plot(data)

# %%
linear = range(10)
nonlinear=[x**2 for x in range(10)]
print(linear)
print(nonlinear)
# Out:
# range(0, 10)
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
plt.grid()
plt.plot(linear, 'r-')
plt.plot(nonlinear, 'g-')
plt.legend(['linear', 'nonlinear'])

# %%
plt.grid()
plt.plot(linear, label='linear')
plt.plot(nonlinear, label='nonlinear')
plt.plot([1,2,4,5,9,2])
plt.legend()

# %%
plt.figure(figsize=(10,4))

plt.subplot(122)
plt.grid()
plt.plot(linear, 'b')

plt.subplot(121)
plt.grid()
plt.plot(nonlinear, 'g')

# %%
import numpy as np

# %%
x = np.arange(-10, 10.01, 0.01)
print(x)
# Out:
# [-10.    -9.99  -9.98 ...   9.98   9.99  10.  ]

# %%
plt.plot(x, x**2)
plt.show()

# %%
x = np.arange(-10, 10.01, 0.01)
plt.plot(x, np.sin(x), x, np.cos(x), x, -x)

# %%
x = np.arange(-10, 10.01, 0.01)
plt.plot(np.sin(x), np.cos(x+0.1))
plt.show()

# %%
x = np.arange(-10, 10.01, 0.01)

plt.figure(figsize=(10, 5))

plt.plot(x, np.sin(x), label=r'$f_1(x)=\sin(x)$')
plt.plot(x, np.cos(x), label=r'$f_2(x)=\cos(x)$')
plt.plot(x, -x, label=r'$f_3(x)=-x$')

plt.xlabel(r'$x$', fontsize=14)
plt.ylabel(r'$f(x)$', fontsize=14)
plt.grid(True)
plt.legend(loc='best', fontsize=12)
plt.savefig('figure_with_legend.png')
plt.show()

# %%
#111111111111111111111111111111111111111111111111
def num2(){
    def f(x):
        if x > 0:
            return 2 * x - 10
        elif x < 0:
            return 2 * abs(x) - 1
        else:
            return 0

    x = np.arange(-10, 10, 0.1)
    y = [f(i) for i in x]

    plt.figure()
    plt.plot(x, y)

    plt.grid()
    plt.title('График функции')
    plt.show()}

# %%
def num1(){
    def f(x):
        if x > 5:
            return 2 * x*x + 10
        elif x < 5:
            return 2 * abs(x+6) - x*x
        else:
            return 0

    x = np.arange(-25, 25, 0.1)
    y = [f(i) for i in x]

    plt.figure()
    plt.plot(x, y)

    plt.grid()
    plt.title('График функции')
    plt.show()
}

# %%
def f(x):
    if x > 3:
        return 5*x-10
    elif x < 3:
        return 2 * abs(x) - 5
    elif x==3:
        return 1

x = np.arange(-20, 20, 0.1)
y = [f(i) for i in x]

plt.figure()
plt.plot(x, y)

plt.grid()
plt.title('График функции')
plt.show()

# %%
def D(x):
    if x > 5:
        return 2 * x*x + 10
    elif x < 5:
        return 2 * abs(x+6) - x*x
    else:
        return 0

def f(x):
    if x > 0:
        return 2 * x - 10
    elif x < 0:
        return 2 * abs(x) - 1
    else:
        return 0

plt.figure(figsize=(8,4))

x = np.arange(-25, 25, 0.1)
y = [D(i) for i in x]

plt.subplot(122)
plt.grid()
plt.title('График функции')
plt.plot(x, y, 'r-')

x = np.arange(-10, 10, 0.1)
y = [f(i) for i in x]

plt.subplot(121)
plt.grid()
plt.title('График функции')
plt.plot(x, y, 'g-')

# %%
#22222222222222222222222222222222222
def s(x):
    return (2+4*x)*(2-3*x)+2*2

x = np.arange(-1, 1, 0.1)
l = [s(i) for i in x]

plt.figure()
plt.plot(x, l)
plt.grid()

# %%
def f(x):
    return abs(x)+x**5

x=np.arange(-2, 1, 0.001)
y=[f(i) for i in x]

plt.figure(figsize=(10,4))

plt.subplot(122)
plt.plot(x,y, 'r-')
plt.grid()

x=np.arange(-1, 1, 0.001)
y=[f(i) for i in x]

plt.subplot(121)
plt.plot(x,y, 'g-')
plt.grid()

# %%
def f(x):
    return (x+1)**2+3*(x+1)

x=np.arange(-10, 10, 0.1)
y=[f(i) for i in x]

plt.grid()
plt.plot(x, y)

# %%
def f(x):
    return (abs(x-5)-np.sin(x))/3+np.sqrt(x*x+2014)*np.cos(2*x)-3

x=np.arange(-50, 50, 1)
y=[f(i) for i in x]

plt.grid()
plt.plot(x, y)

# %%
#33333333333333333333333333
def f(x):
    return -0.23*x*x+x

a= float(input())
b= float(input())
c= float(input())

x=np.arange(a, b, c)
y=[f(i) for i in x]

plt.grid()
plt.plot(x, y)
# Out:
# -10
# 10
# 0.1

# %%
def f(x):
    return np.sqrt(5*x+4*x**3)+4*x+3/np.sin(9*x+71)

a= float(input())
b= float(input())
c= float(input())

x=np.arange(a, b, c)
y=[f(i) for i in x]

plt.grid()
plt.plot(x, y)
# Out:
# 0
# 10
# 0.1

# %%
def f(x):
    return np.sqrt(2+3*x)+72*x+np.tan(4*x+31)

a= float(input())
b= float(input())
c= float(input())

x=np.arange(a, b, c)
y=[f(i) for i in x]

plt.grid()
plt.plot(x, y)
# Out:
# 5
# 10
# 0.1

# %%
def f(x):
    return np.sqrt(5+3/x)+11*x+1/np.tan(2*x+15)

a= float(input())
b= float(input())
c= float(input())

x=np.arange(a, b, c)
y=[f(i) for i in x]

plt.grid()
plt.plot(x, y)
# Out:
# -10
# -7.5
# 0.1
